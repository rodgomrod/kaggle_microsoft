# %%
import pandas as pd
import numpy as np
from sklearn.externals import joblib
import gc

# %%
path = '../../data/test_final_4/part-00000-4beabd79-365b-430b-9894-d5060bb98ce8-c000.csv'

# %%
test = pd.read_csv(path, low_memory=True)

# %%
test.shape
# Out:
# (98160, 123)

# %%
print('Cargando Modelos')
model1 = joblib.load('../../saved_models/lgbc_model_6_1.pkl')
model2 = joblib.load('../../saved_models/lgbc_model_6_2.pkl')
# Out:
# Cargando Modelos

# %%
drop_version = ['AvSigVersion_index', 'EngineVersion_index', 'Census_OSVersion_index', 'AppVersion_index']
sel_cols = [c for c in test.columns if c not in ['MachineIdentifier',
                                                 'HasDetections',
                                                 'Census_DeviceFamily_Windows.Server',
                                                 'Census_DeviceFamily_Windows.Desktop'
                                                 ]+drop_version
            ]

X_test = test.loc[:, sel_cols]
X_machines = test.loc[:, 'MachineIdentifier']
del test
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-2c26eae8e95f> in <module>
#      10 X_machines = test.loc[:, 'MachineIdentifier']
#      11 del test
# ---> 12 del list_
#      13 gc.collect()
#
# NameError: name 'list_' is not defined

# %%
gc.collect()
# Out:
# 24

# %%
print('Realizando y guardando predicciones')
preds1 = model1.predict_proba(X_test)
preds_1 = preds1[:,1]
preds2 = model2.predict_proba(X_test)
preds_2 = preds2[:,1]
# Out:
# Realizando y guardando predicciones

# %%
preds_1
# Out:
# array([0.56187524, 0.34678725, 0.2715036 , ..., 0.51702353, 0.66769516,
#        0.43326288])

# %%
preds_2
# Out:
# array([0.52328631, 0.56217562, 0.24310793, ..., 0.56523151, 0.61960362,
#        0.47652206])

# %%
final_prds = (preds_1+preds_2)/2

# %%
df_prds = pd.DataFrame({'MachineIdentifier': X_machines, 'HasDetections': final_prds})

# %%
df_prds
# Out:
#                       MachineIdentifier  HasDetections
# 0      00000176ac758d54827acd545b6315a5       0.542581
# 1      0000f38dbba7564e7a7cb63522f88ddc       0.454481
# 2      0000f686b28e695811a3e8893bb9cc35       0.257306
# 3      000178eab2e90e6744b5e2fb974d6928       0.647370
# 4      0001a55e53a65c5245eb1d2ce5423cf2       0.641917
# 5      00026be58326a66205257d79c6700014       0.348386
# 6      0003326614b5508e92be9a70a7e2c91f       0.549313
# 7      0005406eede004b85face97389b796f2       0.887093
# 8      00054e0f258af3f7fe46d5f852f07496       0.257785
# 9      00059d8b6abd91ff6ba65ce7094f8f90       0.188307
# 10     00065f55e28ff2560e0be2a048bfb7b4       0.536647
# 11     000cebb9f5a8251a5085b9d3ee4aeb60       0.385280
# 12     000d049e9b81464aca0a9cd261d9c53d       0.498743
# 13     000d175992a01778e8663cd7470cc737       0.252742
# 14     000e30fec46e95edfdce0b03eb525d60       0.499678
# 15     000e74c50fdaf0eecb802c691c7feb0b       0.523649
# 16     000e81a02c0e1fcb5bc4ac7d97637e61       0.471919
# 17     000e91a478da8304eed367f23558196b       0.559336
# 18     000f64edfdd6fa5db1334313a0124fc1       0.475573
# 19     001034bbdfe765ce8bfa3189a63bccf3       0.428080
# 20     0011999760dd9151c4d6471020315f6e       0.501747
# 21     00123a11cca16b23602e62e839f0eaba       0.550116
# 22     001332075b9480a3b10d7db1a8db83fa       0.330175
# 23     00133ff5fa8d060a7117bcbb39c6eceb       0.460478
# 24     0014263dc336058d490f273370eaa99e       0.465805
# 25     001534da74a63169ce129c816361e08e       0.406040
# 26     00155d5044b2405f38c4ddc1d2cf2846       0.508937
# 27     00157140f3691d9d019cd2b8786bd98f       0.529559
# 28     0015a074e381a0dd709eb08a7064430f       0.522205
# 29     0015fee193e66850d5a5c9c9efa0b912       0.515775
# ...                                 ...            ...
# 98130  ffe915c95714d39377316103c9c3e7b9       0.459087
# 98131  ffe94c58d1e6350b4eea4f3b26a740cd       0.521436
# 98132  ffe9e699c58f5c490c098aa04c255254       0.299638
# 98133  ffea022114ba7e067c3fcd29dc3923e6       0.710863
# 98134  ffeabee07023afaa53074e039f5bffda       0.289916
# 98135  ffebc124d0687f566015c6634577bbce       0.447384
# 98136  ffec3eef0d3c4521e913f69a8f3c747f       0.687859
# 98137  ffecac2caaae31125c02f6b4133bea03       0.295370
# 98138  ffece4bf2ed40c05dcc24b6536fe5ea9       0.757092
# 98139  ffefef63169fc2cc6a4921f07a6d1e44       0.542715
# 98140  fff015d376180a2483dbf9e103dad70a       0.702619
# 98141  fff0356d51c2ad38df5cc1f8d8ca37d2       0.847777
# 98142  fff04f2380371444729bc45e2779d4b6       0.830932
# 98143  fff0ecccaf5c5c0ca69e62392a2f9841       0.271424
# 98144  fff173d34c4cfc5303be6b93ca6e29eb       0.558798
# 98145  fff2267228a826546499a72db3bbc2b2       0.469128
# 98146  fff2bb513ac168e99ce4fbffc8539217       0.589805
# 98147  fff4a62c4d8a1a4cb61a908dbd9ccf36       0.603451
# 98148  fff5077f9464918c47baa8e2caa1120b       0.511342
# 98149  fff534a982007d8d7873a05169d02d01       0.576988
# 98150  fff57fc738b2368cc8aaed393d2f8880       0.650996
# 98151  fff5c5792e623229b3833c29e20f2aa1       0.221232
# 98152  fff6928fb9074f35eeeee0b5cc403355       0.423433
# 98153  fff954d25e43ae5f266a9e81cf9ec450       0.538692
# 98154  fffb5cfa28d8c07dac64928e2e69a745       0.308283
# 98155  fffb736f7255b34bbfbdd20ce6dd80b9       0.337410
# 98156  fffc1bd8c6d52565bb6cb7202414c20b       0.588528
# 98157  fffc9f893d44d11d37a68cad6f2e3210       0.541128
# 98158  fffd6994c74d043c2996e61301173297       0.643649
# 98159  fffd84cc545e012bc2fc6c7a259c0fe4       0.454892
#
# [98160 rows x 2 columns]

# %%
submission_list = [
    '../../submissions/ensemble_3.csv',
    '../../submissions/otros_ensemble/sub.csv'
]

# %%
list_ = list()
main = pd.read_csv(submission_list[0])
list_.append(main)
for file_ in submission_list[1:]:
    df = pd.read_csv(file_, usecols=['HasDetections'])
    list_.append(df)

solutions = pd.concat(list_, axis = 1, ignore_index = True)

# %%
solutions.head(20)
# 7853249  fffc645d97cb562aa83377aaaa9ada88  0.313774  1.018840
#
# [1302279 rows x 3 columns]

# %%
ensemble = solutions.iloc[:,1]*0.5 + solutions.iloc[:,2]*0.5

# %%
ensemble
# Out:
# 0          0.683695
# 1          0.607547
# 2          0.837515
# 3          0.519062
# 4          0.699168
# 5          0.691782
# 6          0.338073
# 7          0.394465
# 8          0.577634
# 9          0.444681
# 10         0.533783
# 11         0.591299
# 12         0.476698
# 13         0.856858
# 14         0.592371
# 15         0.513362
# 16         0.289747
# 17         0.499688
# 18         0.475609
# 19         0.481823
# 20         0.351602
# 21         0.936615
# 22         0.729891
# 23         0.710283
# 24         0.641107
# 25         0.615660
# 26         0.758784
# 27         0.492897
# 28         0.544794
# 29         0.672298
#              ...
# 7853223    0.719935
# 7853224    0.331062
# 7853225    0.421881
# 7853226    0.699395
# 7853227    0.569871
# 7853228    0.513790
# 7853229    0.592942
# 7853230    0.657851
# 7853231    0.491791
# 7853232    0.595340
# 7853233    0.572427
# 7853234    0.765267
# 7853235    0.664977
# 7853236    0.276625
# 7853237    0.706081
# 7853238    0.531833
# 7853239    0.455166
# 7853240    0.649968
# 7853241    0.812363
# 7853242    0.489483
# 7853243    0.542436
# 7853244    0.512272
# 7853245    0.805705
# 7853246    0.460629
# 7853247    0.669832
# 7853248    0.505325
# 7853249    0.666307
# 7853250    0.552203
# 7853251    0.578305
# 7853252    0.518766
# Length: 7853253, dtype: float64

# %%
df_sol = solutions.iloc[:,list(range(1, len(submission_list)+1))]

# %%
df_sol.head()
# Out:
#           1         2         3         4         5         6
# 0  0.565578  0.513228  0.613467  0.532546  0.529662  0.557255
# 1  0.302690  0.289408  0.285836  0.316043  0.356575  0.350641
# 2  0.734579  0.723681  0.734906  0.716263  0.731377  0.714496
# 3  0.452211  0.438657  0.477922  0.434049  0.473053  0.446482
# 4  0.671748  0.696052  0.691509  0.658294  0.675461  0.647062

# %%
df_sol['avg'] = solutions.mean(axis=1)

# %%
df_sol.head(20)
# Out:
#            1         2         3         4         5         6       avg
# 0   0.565578  0.513228  0.613467  0.532546  0.529662  0.557255  0.551956
# 1   0.302690  0.289408  0.285836  0.316043  0.356575  0.350641  0.316865
# 2   0.734579  0.723681  0.734906  0.716263  0.731377  0.714496  0.725884
# 3   0.452211  0.438657  0.477922  0.434049  0.473053  0.446482  0.453729
# 4   0.671748  0.696052  0.691509  0.658294  0.675461  0.647062  0.673354
# 5   0.594425  0.554841  0.696732  0.610780  0.651937  0.604638  0.618892
# 6   0.281012  0.266408  0.294683  0.283191  0.289553  0.305385  0.286705
# 7   0.519690  0.518324  0.548525  0.544067  0.525206  0.517285  0.528850
# 8   0.749942  0.751693  0.771173  0.747856  0.764058  0.731281  0.752667
# 9   0.551693  0.518722  0.485949  0.550180  0.581779  0.563843  0.542028
# 10  0.482110  0.447187  0.445714  0.463455  0.520712  0.589149  0.491388
# 11  0.621674  0.604900  0.646187  0.642019  0.512400  0.615164  0.607057
# 12  0.270051  0.269047  0.292122  0.269613  0.308827  0.262483  0.278690
# 13  0.665757  0.634687  0.697170  0.686194  0.711540  0.722170  0.686253
# 14  0.712903  0.729432  0.745311  0.719371  0.698808  0.646404  0.708705
# 15  0.424103  0.400791  0.353575  0.415968  0.364610  0.442942  0.400331
# 16  0.234341  0.212961  0.220334  0.231165  0.184458  0.260610  0.223978
# 17  0.483717  0.478219  0.565020  0.463091  0.547400  0.527626  0.510845
# 18  0.265709  0.257162  0.252339  0.275694  0.229136  0.235261  0.252550
# 19  0.385531  0.369593  0.398299  0.396857  0.376040  0.403111  0.388238

# %%
df_sol['avg'].min()
# Out:
# 0.0016632608502256524

# %%
final_df = pd.DataFrame({'MachineIdentifier': solutions[0], 'HasDetections': ensemble})

# %%
final_df.head()
# Out:
#                   MachineIdentifier  HasDetections
# 0  00001dcfc3f82d68d6eae9cad4a3e07c       0.683695
# 1  000047fcfba5075a43a39cc488d4a9f1       0.607547
# 2  0000d68052a924812e9b38155d97791d       0.837515
# 3  000198cb3bb137d8f312017b268062ce       0.519062
# 4  00020420d618b4fb2a455e66b47c2a70       0.699168

# %%
final_df.to_csv('../../submissions/ensemble_11.csv', index=None)

# %% [markdown]
# Estiramiento prob!!!

# %%
import copy

# %%
# >>> df = pd.DataFrame(np.arange(10).reshape(-1, 2), columns=['A', 'B'])
# >>> m = df % 3 == 0
# >>> df.where(m, -df)

# >>> s = pd.Series(range(5))
# >>> s.where(s > 0)

# %%
imps = copy.deepcopy(final_df['HasDetections'])

# %%
imps.head(10)
# Out:
# 0    0.539403
# 1    0.296049
# 2    0.729130
# 3    0.445434
# 4    0.683900
# 5    0.574633
# 6    0.273710
# 7    0.519007
# 8    0.750818
# 9    0.535207
# Name: HasDetections, dtype: float64

# %%
# imps = final_df['HasDetections']
imps.where((0.45 > imps) | (imps > 0.55), 1 - imps, inplace=True)
# imps.where(0.45 < imps < 0.5, 1 - imps, inplace=True)
# imps.where(imps > 0, 0, inplace=True)
# imps.where(imps < 1, 1, inplace=True)

# %%
# imps.shape

# %%
imps.head(10)
# Out:
# 0    0.460597
# 1    0.296049
# 2    0.729130
# 3    0.445434
# 4    0.683900
# 5    0.574633
# 6    0.273710
# 7    0.480993
# 8    0.750818
# 9    0.464793
# Name: HasDetections, dtype: float64

# %%
print(imps.max(), imps.min())
# Out:
# 0.9942492869435667 0.001800180977778512

# %%
final_df_est = pd.DataFrame({'MachineIdentifier': solutions[0], 'HasDetections':imps})

# %%
final_df_est.head()
# Out:
#                   MachineIdentifier  HasDetections
# 0  00001dcfc3f82d68d6eae9cad4a3e07c       0.460597
# 1  000047fcfba5075a43a39cc488d4a9f1       0.296049
# 2  0000d68052a924812e9b38155d97791d       0.729130
# 3  000198cb3bb137d8f312017b268062ce       0.445434
# 4  00020420d618b4fb2a455e66b47c2a70       0.683900

# %%
final_df_est.to_csv('../../submissions/ensemble_9.csv', index=None)
